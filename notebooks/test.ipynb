# %%
import pandas as pd

S3_BUCKET = 'de-project2-nppes'
S3_PREFIX = 'kssnppes2/'

file_path = f"s3://{S3_BUCKET}/{S3_PREFIX}nppes_sample.csv"

nppes_sample = pd.read_csv(file_path)
nppes_sample.head()
# Out:
#           NPI  Entity Type Code  Replacement NPI  \
# 0  1679576722               1.0              NaN
# 1  1588667638               1.0              NaN
# 2  1497758544               2.0              NaN
# 3  1306849450               NaN              NaN
# 4  1215930367               1.0              NaN
#
#   Employer Identification Number (EIN)  \
# 0                                  NaN
# 1                                  NaN
# 2                            <UNAVAIL>
# 3                                  NaN
# 4                                  NaN
#
#   Provider Organization Name (Legal Business Name)  \
# 0                                              NaN
# 1                                              NaN
# 2           CUMBERLAND COUNTY HOSPITAL SYSTEM, INC
# 3                                              NaN
# 4                                              NaN
#
#   Provider Last Name (Legal Name) Provider First Name Provider Middle Name  \
# ...

# %%
df.shape
df.columns
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Columns: 330 entries, NPI to Certification Date
# dtypes: float64(184), int64(1), str(145)
# memory usage: 2.7 MB

# %%
df.columns
# Out:
# Index(['NPI', 'Entity Type Code', 'Replacement NPI',
#        'Employer Identification Number (EIN)',
#        'Provider Organization Name (Legal Business Name)',
#        'Provider Last Name (Legal Name)', 'Provider First Name',
#        'Provider Middle Name', 'Provider Name Prefix Text',
#        'Provider Name Suffix Text',
#        ...
#        'Healthcare Provider Taxonomy Group_7',
#        'Healthcare Provider Taxonomy Group_8',
#        'Healthcare Provider Taxonomy Group_9',
#        'Healthcare Provider Taxonomy Group_10',
#        'Healthcare Provider Taxonomy Group_11',
#        'Healthcare Provider Taxonomy Group_12',
#        'Healthcare Provider Taxonomy Group_13',
#        'Healthcare Provider Taxonomy Group_14',
#        'Healthcare Provider Taxonomy Group_15', 'Certification Date'],
#       dtype='str', length=330)

# %%
nppes_sample.isnull().sum()
# Out:
# NPI                                                    0
# Entity Type Code                                      79
# Replacement NPI                                     1000
# Employer Identification Number (EIN)                 812
# Provider Organization Name (Legal Business Name)     812
#                                                     ...
# Healthcare Provider Taxonomy Group_12               1000
# Healthcare Provider Taxonomy Group_13               1000
# Healthcare Provider Taxonomy Group_14               1000
# Healthcare Provider Taxonomy Group_15               1000
# Certification Date                                   753
# Length: 330, dtype: int64

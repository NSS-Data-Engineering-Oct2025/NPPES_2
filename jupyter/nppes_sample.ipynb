# %%
import pandas as pd
from dotenv import load_dotenv

# %%
load_dotenv()
S3_BUCKET = 'de-project2-nppes'
S3_PREFIX = 'kssnppes2/'

file_path = f"s3://{S3_BUCKET}/{S3_PREFIX}nppes_sample.csv"

df = pd.read_csv(file_path)
df.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/.local/lib/python3.13/site-packages/pandas/compat/_optional.py:158, in import_optional_dependency(name, extra, min_version, errors)
#     157 try:
# --> 158     module = importlib.import_module(name)
#     159 except ImportError as err:
#
# File /usr/local/lib/python3.13/importlib/__init__.py:88, in import_module(name, package)
#      87         level += 1
# ---> 88 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1324, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'fsspec'
#
# The above exception was the direct cause of the following exception:
#
# ...
